# %%
#!/usr/bin/env python3
"""
CiNii Articleのjsonを連結するに
"""

import urllib3
import urllib.parse
import certifi
import pandas as pd
import csv
import sys
import json
import time

#APPID = "xxxxx" # APPIDはCiNiiで取得してセット
APPID = "CiNii09-89ef94917d5946d2a0dae832519f760b"
keyword2 = "大向一輝"
keyword = urllib.parse.quote(keyword2)
count = 50

req_url = 'https://ci.nii.ac.jp/books/opensearch/search?format=json'
req_url = req_url + "&appid=" + APPID
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED', ca_certs=certifi.where())

def req(keyword, start):
   req_url2 = req_url + "&q=" + keyword + "&start=" + str(start) + "&count=" + str(count)
   print(req_url2)
   response = http.request('GET', req_url2)
   json_data = response.data.decode('utf-8')
   time.sleep(0.5)
   return json_data

data_dict1 = json.loads(req(keyword,1))
totalResults = data_dict1["@graph"][0]["opensearch:totalResults"] # 総件数
print("totalResults: ",totalResults)

data_dict = pd.DataFrame()

num = 1
while True:
    json_data2 = req(keyword,num)
    try:
        data_dict = data_dict.append( pd.read_json(json.dumps(json.loads(json_data2)["@graph"][0]["items"])) ,sort="true")
    except Exception:
        pass
    # 
    num = num + count
    if num > int(totalResults) :
        break

# %%
data_dict.tail()

# %%
# DataFrameの列@idからlistを作成
l_id = data_dict['@id'].values.tolist()
# l_id  # ->['http://ci.nii.ac.jp/ncid/BN07817320', 'http://ci.nii.ac.jp/ncid/BN05475634',,,,,,

# %%
# １件ごとの json を出力
def req(id):
    req_url = id + ".json"
    # print(req_url)
    response = http.request('GET', req_url)
    json_data= response.data.decode('utf-8')
    # json_data = json_data2.pop('bibo:owner')
    time.sleep(0.2)
    return json_data

data_dictj = {}
data_dictj2 = {}
# print(type(data_dictj))

for id in l_id:
    print(type(data_dictj), id)
    # idをキーにして、連結
    data_dictj[id] = json.loads(req(id))
    # 所蔵館と'@context'のデータ要素を削除
    del data_dictj[id]['@graph'][0]['bibo:owner'],data_dictj[id]['@context']

# %%
# ensure_ascii オプションがTrueだと非ASCII文字を全て "\uXXXX" の形にエスケープ
# with open('test2.json', 'w', encoding='utf_8_sig') as f:
with open('test2.json', 'w', encoding='utf_8') as f:
    json.dump(data_dictj, f, indent=4, ensure_ascii=False)
# with open('test2.json', encoding='unicode-escape') as f:    
with open('test2.json', encoding='utf-8') as f:
    print(f.read())

# %%
# ensure_ascii オプションがTrueだと非ASCII文字を全て "\uXXXX" の形にエスケープ
# with open('test2.json', 'w', encoding='utf_8_sig') as f:
with open('test2.json', 'w', encoding='utf_8') as f:
    json.dump(data_dictj, f, indent=4, ensure_ascii=False)
# with open('test2.json', encoding='unicode-escape') as f:    
with open('test2.json', encoding='utf-8') as f:
    print(f.read())

# %%
# ensure_ascii オプションがTrueだと非ASCII文字を全て "\uXXXX" の形にエスケープ
# with open('test2.json', 'w', encoding='utf_8_sig') as f:
with open('test2.json', 'w', encoding='utf_8') as f:
    json.dump(data_dictj, f, indent=4, ensure_ascii=False)
# with open('test2.json', encoding='unicode-escape') as f:    
with open('test2.json', encoding='utf-8') as f:
    print(f.read())

# %%
print(data_dictj)
# print(data_dictj["@graph"][0]) #

# %%
# ensure_ascii オプションがTrueだと非ASCII文字を全て "\uXXXX" の形にエスケープ
# with open('test2.json', 'w', encoding='utf_8_sig') as f:
with open('test1.json', 'w', encoding='utf_8') as f:
    json.dump(data_dictj, f, indent=4, ensure_ascii=False)
# with open('test2.json', encoding='unicode-escape') as f:    
with open('test1.json', encoding='utf-8') as f:
    print(f.read())

# %%
# dict 型のキー一覧の先頭を取得する next(iter(data_dictj))
graph_keys = data_dictj[next(iter(data_dictj))]['@graph'][0].keys()
list(dict.fromkeys(graph_keys))
print(graph_keys)

# %%
graph_keys = []
# dict 型のキー一覧の先頭を取得する next(iter(data_dictj))
# 全データからキーを取得して追記する。
for k in data_dictj:
    graph_keys.extend(data_dictj[k]['@graph'][0].keys())
    # print(graph_keys)
# 順序を維持してユニークなキーを取得    
graph_keys = list(dict.fromkeys(graph_keys))
print(graph_keys)

# %%
import csv
with open('test1.csv', 'w', encoding='utf_8') as f:
    writer = csv.DictWriter(f, graph_keys)
    writer.writeheader()
    # writer.writerows(data_dictj[next(iter(data_dictj))]['@graph'])
    for k in data_dictj:
        # writer.writeheader()
        writer.writerows(data_dictj[k]['@graph'])
# with open('test2.json', encoding='unicode-escape') as f:    
with open('test1.csv', encoding='utf-8') as f:
    print(f.read())

# %%
for k in data_dictj:
    print(k)

# %%
# 連結方法をlisに変える
# １件ごとの json を出力
def req(id):
    req_url = id + ".json"
    # print(req_url)
    response = http.request('GET', req_url)
    json_data= response.data.decode('utf-8')
    # json_data = json_data2.pop('bibo:owner')
    time.sleep(0.2)
    return json_data

data_listj = []

# for i,word in enumerate(['a','b','c']):
for i,id in enumerate(l_id):
    print(i, type(data_listj), id)
    # list連結
    # data_listj.append(json.loads(req(id)).copy())    
    data_listj.append(json.loads(req(id)))
    # 所蔵館と'@context'のデータ要素を削除
    # del data_dictj[id]['@graph'][0]['bibo:owner'],data_dictj[id]['@context']
    del data_listj[i]['@graph'][0]['bibo:owner'],data_listj[i]['@context']

# %%
# ensure_ascii オプションがTrueだと非ASCII文字を全て "\uXXXX" の形にエスケープ
# with open('test2.json', 'w', encoding='utf_8_sig') as f:
with open('test2.json', 'w', encoding='utf_8') as f:
    json.dump(data_listj, f, indent=4, ensure_ascii=False)
# with open('test2.json', encoding='unicode-escape') as f:    
with open('test2.json', encoding='utf-8') as f:
    print(f.read())

# %%
import csv

with open('test2.csv', 'w', encoding='utf_8') as f:
    writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
    # writer.writeheader()
    writer.writerow(data_listj)

# %%
# 連結方法をlisに変える
# 辞書をリストに変換
# １件ごとの json を出力
def req(id):
    req_url = id + ".json"
    # print(req_url)
    response = http.request('GET', req_url)
    json_data= response.data.decode('utf-8')
    time.sleep(0.2)
    return json_data

data_list2 = []

# for i,word in enumerate(['a','b','c']):
for i,id in enumerate(l_id):
    print(i, type(data_list2), id)
    # list連結
    # data_listj.append(json.loads(req(id)).copy())    
    data_list2.append(list(json.loads(req(id)).items()))
    # 所蔵館と'@context'のデータ要素を削除
    # del data_dictj[id]['@graph'][0]['bibo:owner'],data_dictj[id]['@context']
    # 'dict_items' object is not subscriptable と出るのでとりあえず以下を外す
    del data_list2[i]['@graph'][0]['bibo:owner'],data_list2[i]['@context']
# Out:
# 0 <class 'list'> https://ci.nii.ac.jp/ncid/BA8164687X
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-5940a77f0183> in <module>
#      21     # del data_dictj[id]['@graph'][0]['bibo:owner'],data_dictj[id]['@context']
#      22     # 'dict_items' object is not subscriptable と出るのでとりあえず以下を外す
# ---> 23     del data_list2[i]['@graph'][0]['bibo:owner'],data_list2[i]['@context']
#
# TypeError: list indices must be integers or slices, not str

# %%
print('あ',data_list2[0][0]) # '@context'
print('い',data_list2[0][2][1]) # '@graph'
print('う',data_list2[0][2][1][0]['bibo:owner']) # '@graph'
# Out:
# あ ('@context', {'owl': 'http://www.w3.org/2002/07/owl#', 'bibo': 'http://purl.org/ontology/bibo/', 'foaf': 'http://xmlns.com/foaf/0.1/', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#', 'prism': 'http://prismstandard.org/namespaces/basic/2.0/', 'cinii': 'http://ci.nii.ac.jp/ns/1.0/', 'dc': 'http://purl.org/dc/elements/1.1/', 'dcterms': 'http://purl.org/dc/terms/'})
# い [{'@id': 'https://ci.nii.ac.jp/ncid/BA8164687X#entity', '@type': 'bibo:Book', 'foaf:isPrimaryTopicOf': {'@id': 'https://ci.nii.ac.jp/ncid/BA8164687X.json'}, 'dc:title': [{'@value': 'ウェブがわかる本'}, {'@value': 'ウェブ ガ ワカル ホン', '@language': 'ja-hrkt'}], 'dc:creator': '大向一輝著', 'dc:publisher': ['岩波書店'], 'dcterms:extent': 'ix, 179p', 'cinii:size': '18cm', 'dc:language': 'jpn', 'dc:date': '2007', 'cinii:ncid': 'BA8164687X', 'cinii:ownerCount': '165', 'foaf:maker': [{'@id': 'https://ci.nii.ac.jp/author/DA15839119#entity', '@type': 'foaf:Person', 'foaf:name': [{'@value': '大向, 一輝'}, {'@value': 'オオムカイ, イッキ', '@language': 'ja-hrkt'}]}], 'bibo:owner': [{'@id': 'https://ci.nii.ac.jp/library/FA016536', '@type': 'foaf:Organization', 'foaf:name': '富山高等専門学校 図書館情報センター本郷', 'rdfs:seeAlso': {'@id': 'https://libopac3-c.nagaokaut.ac.jp/opac/opac_openurl?kscode=018&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA001266', '@type': 'foaf:Organization', 'foaf:name': '北海道教育大学 附属図書館 旭川館', 'rdfs:seeAlso': {'@id': 'http://s-opac.sap.hokkyodai.ac.jp/mylimedio/search/search.do?target=local&mode=comp&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA008210', '@type': 'foaf:Organization', 'foaf:name': '大手前大学・大手前短期大学 図書館', 'rdfs:seeAlso': {'@id': 'https://opac.otemae.ac.jp/opac/opac_openurl/?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA008323', '@type': 'foaf:Organization', 'foaf:name': '神戸女子大学 図書館', 'rdfs:seeAlso': {'@id': 'https://lib.yg.kobe-wu.ac.jp/opac/opac_openurl/?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA004934', '@type': 'foaf:Organization', 'foaf:name': '青山学院大学 万代記念図書館(相模原分館)', 'rdfs:seeAlso': {'@id': 'https://www.agulin.aoyama.ac.jp/opac/opac_openurl/?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA004832', '@type': 'foaf:Organization', 'foaf:name': '文教大学 湘南図書館', 'rdfs:seeAlso': {'@id': 'http://opac.bunkyo.ac.jp/mylimedio/search/search.do?target=local&mode=comp&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA004490', '@type': 'foaf:Organization', 'foaf:name': '東北工業大学 附属図書館', 'rdfs:seeAlso': {'@id': 'http://opac.tohtech.ac.jp/mylimedio/search/search.do?mode=comp&target=local&category-mgz=1&category-book=1&annex=all&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA019363', '@type': 'foaf:Organization', 'foaf:name': '長野県立大学 図書館', 'rdfs:seeAlso': {'@id': 'https://u-nagano-lib.opac.jp/opac/ncid_search?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA007149', '@type': 'foaf:Organization', 'foaf:name': '岐阜聖徳学園大学 羽島キャンパス図書館', 'rdfs:seeAlso': {'@id': 'http://carin.shotoku.ac.jp/intrasite/CARINOPACLINK.HTM?OAL=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA017404', '@type': 'foaf:Organization', 'foaf:name': '仙台高等専門学校 名取キャンパス 図書館', 'rdfs:seeAlso': {'@id': 'https://libopac3-c.nagaokaut.ac.jp/opac/opac_search/?kscode=008&smode=1'}}, {'@id': 'https://ci.nii.ac.jp/library/FA015599', '@type': 'foaf:Organization', 'foaf:name': '松山東雲女子大学・松山東雲短期大学 図書館', 'rdfs:seeAlso': {'@id': 'https://lib.shinonome.ac.jp/opac4/opac/ncid_search?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA002939', '@type': 'foaf:Organization', 'foaf:name': '大阪教育大学 附属図書館', 'rdfs:seeAlso': {'@id': 'https://opac-ir.lib.osaka-kyoiku.ac.jp/webopac/ufirdi.do?ufi_target=ctlsrh&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA001889', '@type': 'foaf:Organization', 'foaf:name': '東京学芸大学 附属図書館', 'rdfs:seeAlso': {'@id': 'https://library.u-gakugei.ac.jp/mylimedio/search/search.do?target=local&mode=comp&annex=all&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA004049', '@type': 'foaf:Organization', 'foaf:name': '神戸市外国語大学 学術情報センター'}, {'@id': 'https://ci.nii.ac.jp/library/FA006758', '@type': 'foaf:Organization', 'foaf:name': '立教大学 図書館', 'rdfs:seeAlso': {'@id': 'https://opac.rikkyo.ac.jp/opac/opac_openurl/?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA019793', '@type': 'foaf:Organization', 'foaf:name': '尚絅学院大学 図書館'}, {'@id': 'https://ci.nii.ac.jp/library/FA016616' ...
# う [{'@id': 'https://ci.nii.ac.jp/library/FA016536', '@type': 'foaf:Organization', 'foaf:name': '富山高等専門学校 図書館情報センター本郷', 'rdfs:seeAlso': {'@id': 'https://libopac3-c.nagaokaut.ac.jp/opac/opac_openurl?kscode=018&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA001266', '@type': 'foaf:Organization', 'foaf:name': '北海道教育大学 附属図書館 旭川館', 'rdfs:seeAlso': {'@id': 'http://s-opac.sap.hokkyodai.ac.jp/mylimedio/search/search.do?target=local&mode=comp&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA008210', '@type': 'foaf:Organization', 'foaf:name': '大手前大学・大手前短期大学 図書館', 'rdfs:seeAlso': {'@id': 'https://opac.otemae.ac.jp/opac/opac_openurl/?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA008323', '@type': 'foaf:Organization', 'foaf:name': '神戸女子大学 図書館', 'rdfs:seeAlso': {'@id': 'https://lib.yg.kobe-wu.ac.jp/opac/opac_openurl/?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA004934', '@type': 'foaf:Organization', 'foaf:name': '青山学院大学 万代記念図書館(相模原分館)', 'rdfs:seeAlso': {'@id': 'https://www.agulin.aoyama.ac.jp/opac/opac_openurl/?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA004832', '@type': 'foaf:Organization', 'foaf:name': '文教大学 湘南図書館', 'rdfs:seeAlso': {'@id': 'http://opac.bunkyo.ac.jp/mylimedio/search/search.do?target=local&mode=comp&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA004490', '@type': 'foaf:Organization', 'foaf:name': '東北工業大学 附属図書館', 'rdfs:seeAlso': {'@id': 'http://opac.tohtech.ac.jp/mylimedio/search/search.do?mode=comp&target=local&category-mgz=1&category-book=1&annex=all&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA019363', '@type': 'foaf:Organization', 'foaf:name': '長野県立大学 図書館', 'rdfs:seeAlso': {'@id': 'https://u-nagano-lib.opac.jp/opac/ncid_search?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA007149', '@type': 'foaf:Organization', 'foaf:name': '岐阜聖徳学園大学 羽島キャンパス図書館', 'rdfs:seeAlso': {'@id': 'http://carin.shotoku.ac.jp/intrasite/CARINOPACLINK.HTM?OAL=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA017404', '@type': 'foaf:Organization', 'foaf:name': '仙台高等専門学校 名取キャンパス 図書館', 'rdfs:seeAlso': {'@id': 'https://libopac3-c.nagaokaut.ac.jp/opac/opac_search/?kscode=008&smode=1'}}, {'@id': 'https://ci.nii.ac.jp/library/FA015599', '@type': 'foaf:Organization', 'foaf:name': '松山東雲女子大学・松山東雲短期大学 図書館', 'rdfs:seeAlso': {'@id': 'https://lib.shinonome.ac.jp/opac4/opac/ncid_search?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA002939', '@type': 'foaf:Organization', 'foaf:name': '大阪教育大学 附属図書館', 'rdfs:seeAlso': {'@id': 'https://opac-ir.lib.osaka-kyoiku.ac.jp/webopac/ufirdi.do?ufi_target=ctlsrh&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA001889', '@type': 'foaf:Organization', 'foaf:name': '東京学芸大学 附属図書館', 'rdfs:seeAlso': {'@id': 'https://library.u-gakugei.ac.jp/mylimedio/search/search.do?target=local&mode=comp&annex=all&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA004049', '@type': 'foaf:Organization', 'foaf:name': '神戸市外国語大学 学術情報センター'}, {'@id': 'https://ci.nii.ac.jp/library/FA006758', '@type': 'foaf:Organization', 'foaf:name': '立教大学 図書館', 'rdfs:seeAlso': {'@id': 'https://opac.rikkyo.ac.jp/opac/opac_openurl/?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA019793', '@type': 'foaf:Organization', 'foaf:name': '尚絅学院大学 図書館'}, {'@id': 'https://ci.nii.ac.jp/library/FA016616', '@type': 'foaf:Organization', 'foaf:name': '明石工業高等専門学校 図書館'}, {'@id': 'https://ci.nii.ac.jp/library/FA001685', '@type': 'foaf:Organization', 'foaf:name': '宇都宮大学 附属図書館', 'rdfs:seeAlso': {'@id': 'http://opac.lib.utsunomiya-u.ac.jp/opc/recordID/catalog.bib/BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA003873', '@type': 'foaf:Organization', 'foaf:name': '名古屋市立大学 総合情報センター 山の畑分館', 'rdfs:seeAlso': {'@id': 'https://ncu-m-opac.adm.nagoya-cu.ac.jp/webopac/ufirdi.do?ufi_target=ctlsrh&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA001222', '@type': 'foaf:Organization', 'foaf:name': '北海道大学 大学院保健科学研究院', 'rdfs:seeAlso': {'@id' ...

# %%
print(data_list2)
# Out:
# [[('@context', {'owl': 'http://www.w3.org/2002/07/owl#', 'bibo': 'http://purl.org/ontology/bibo/', 'foaf': 'http://xmlns.com/foaf/0.1/', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#', 'prism': 'http://prismstandard.org/namespaces/basic/2.0/', 'cinii': 'http://ci.nii.ac.jp/ns/1.0/', 'dc': 'http://purl.org/dc/elements/1.1/', 'dcterms': 'http://purl.org/dc/terms/'}), ('@id', 'https://ci.nii.ac.jp/ncid/BA8164687X.json'), ('@graph', [{'@id': 'https://ci.nii.ac.jp/ncid/BA8164687X#entity', '@type': 'bibo:Book', 'foaf:isPrimaryTopicOf': {'@id': 'https://ci.nii.ac.jp/ncid/BA8164687X.json'}, 'dc:title': [{'@value': 'ウェブがわかる本'}, {'@value': 'ウェブ ガ ワカル ホン', '@language': 'ja-hrkt'}], 'dc:creator': '大向一輝著', 'dc:publisher': ['岩波書店'], 'dcterms:extent': 'ix, 179p', 'cinii:size': '18cm', 'dc:language': 'jpn', 'dc:date': '2007', 'cinii:ncid': 'BA8164687X', 'cinii:ownerCount': '165', 'foaf:maker': [{'@id': 'https://ci.nii.ac.jp/author/DA15839119#entity', '@type': 'foaf:Person', 'foaf:name': [{'@value': '大向, 一輝'}, {'@value': 'オオムカイ, イッキ', '@language': 'ja-hrkt'}]}], 'bibo:owner': [{'@id': 'https://ci.nii.ac.jp/library/FA016536', '@type': 'foaf:Organization', 'foaf:name': '富山高等専門学校 図書館情報センター本郷', 'rdfs:seeAlso': {'@id': 'https://libopac3-c.nagaokaut.ac.jp/opac/opac_openurl?kscode=018&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA001266', '@type': 'foaf:Organization', 'foaf:name': '北海道教育大学 附属図書館 旭川館', 'rdfs:seeAlso': {'@id': 'http://s-opac.sap.hokkyodai.ac.jp/mylimedio/search/search.do?target=local&mode=comp&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA008210', '@type': 'foaf:Organization', 'foaf:name': '大手前大学・大手前短期大学 図書館', 'rdfs:seeAlso': {'@id': 'https://opac.otemae.ac.jp/opac/opac_openurl/?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA008323', '@type': 'foaf:Organization', 'foaf:name': '神戸女子大学 図書館', 'rdfs:seeAlso': {'@id': 'https://lib.yg.kobe-wu.ac.jp/opac/opac_openurl/?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA004934', '@type': 'foaf:Organization', 'foaf:name': '青山学院大学 万代記念図書館(相模原分館)', 'rdfs:seeAlso': {'@id': 'https://www.agulin.aoyama.ac.jp/opac/opac_openurl/?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA004832', '@type': 'foaf:Organization', 'foaf:name': '文教大学 湘南図書館', 'rdfs:seeAlso': {'@id': 'http://opac.bunkyo.ac.jp/mylimedio/search/search.do?target=local&mode=comp&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA004490', '@type': 'foaf:Organization', 'foaf:name': '東北工業大学 附属図書館', 'rdfs:seeAlso': {'@id': 'http://opac.tohtech.ac.jp/mylimedio/search/search.do?mode=comp&target=local&category-mgz=1&category-book=1&annex=all&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA019363', '@type': 'foaf:Organization', 'foaf:name': '長野県立大学 図書館', 'rdfs:seeAlso': {'@id': 'https://u-nagano-lib.opac.jp/opac/ncid_search?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA007149', '@type': 'foaf:Organization', 'foaf:name': '岐阜聖徳学園大学 羽島キャンパス図書館', 'rdfs:seeAlso': {'@id': 'http://carin.shotoku.ac.jp/intrasite/CARINOPACLINK.HTM?OAL=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA017404', '@type': 'foaf:Organization', 'foaf:name': '仙台高等専門学校 名取キャンパス 図書館', 'rdfs:seeAlso': {'@id': 'https://libopac3-c.nagaokaut.ac.jp/opac/opac_search/?kscode=008&smode=1'}}, {'@id': 'https://ci.nii.ac.jp/library/FA015599', '@type': 'foaf:Organization', 'foaf:name': '松山東雲女子大学・松山東雲短期大学 図書館', 'rdfs:seeAlso': {'@id': 'https://lib.shinonome.ac.jp/opac4/opac/ncid_search?ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA002939', '@type': 'foaf:Organization', 'foaf:name': '大阪教育大学 附属図書館', 'rdfs:seeAlso': {'@id': 'https://opac-ir.lib.osaka-kyoiku.ac.jp/webopac/ufirdi.do?ufi_target=ctlsrh&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/library/FA001889', '@type': 'foaf:Organization', 'foaf:name': '東京学芸大学 附属図書館', 'rdfs:seeAlso': {'@id': 'https://library.u-gakugei.ac.jp/mylimedio/search/search.do?target=local&mode=comp&annex=all&ncid=BA8164687X'}}, {'@id': 'https://ci.nii.ac.jp/ ...

# %%
# ensure_ascii オプションがTrueだと非ASCII文字を全て "\uXXXX" の形にエスケープ
# with open('test2.json', 'w', encoding='utf_8_sig') as f:
with open('test3.json', 'w', encoding='utf_8') as f:
    json.dump(data_list2, f, indent=4, ensure_ascii=False)
# with open('test2.json', encoding='unicode-escape') as f:    
with open('test3.json', encoding='utf-8') as f:
    print(f.read())
